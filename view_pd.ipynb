# %%
import pandas as pd
import os
import json
from IPython.display import display # Importante para mostrar tablas dentro de bloques

# CONFIGURACIÓN DE PANDAS
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None) # Para ver todas las nuevas columnas

path = 'out'
nombre_archivo = 'sync_preview.csv' 
full_path = os.path.join(path, nombre_archivo)

try:
    if not os.path.exists(full_path):
        print(f"Error: El archivo no existe en {full_path}")
    else:
        df = pd.read_csv(full_path)
        
        # 1. Seleccionamos columnas (usamos copy para evitar alertas de SettingWithCopy)
        df = df[["idRecurso", "Organisme", "payload_json"]].copy()
        
        # 2. Convertir string a diccionario si es necesario
        def parse_json(x):
            try:
                return json.loads(x) if isinstance(x, str) else x
            except:
                return {} # En caso de error en el JSON, devuelve dict vacío

        df['payload_json'] = df['payload_json'].apply(parse_json)

        # 3. Aplanar el JSON
        df_payload = pd.json_normalize(df['payload_json'])

        # 4. Concatenar y eliminar la columna original
        df_final = pd.concat([df.drop(columns=['payload_json']).reset_index(drop=True), 
                             df_payload.reset_index(drop=True)], axis=1)

        print(f"Éxito: Se han generado {df_final.shape[1]} columnas.")
        
        # 5. MOSTRAR EL RESULTADO EXPLÍCITAMENTE
        #display(df_final.head(50))
        df_organisme = df_final['Organisme'].value_counts().reset_index()
        df_organisme.columns = ['Organisme', 'Count']
        display(df_organisme)

except Exception as e:
    print(f"Se produjo un error durante el proceso: {e}")
# Out:
# Éxito: Se han generado 22 columnas.
#     idRecurso  \
# 0       74756
# 1       36039
# 2       33844
# 3       35754
# 4       74468
# 5       86736
# 6       74211
# 7       75557
# 8       37483
# 9       86768
# 10      74573
# 11       3819
# 12       2733
# 13      41695
# 14      53019
# 15      31754
# 16      31455
# 17       1477
# 18       5042
# 19       2534
# 20       3815
# 21      24508
# 22      22895
# 23       5417
# 24      39308
# 25       5327
# 26       1963
# 27       5329
# 28      47671
# 29      33841
# 30      86740
# 31      32409
# 32       5142
# 33       2407
# 34       4108
# 35      87074
# 36      53868
# 37      22685
# 38      43048
# 39      39335
# 40      22891
# 41      24829
# 42      42519
# 43       5202
# 44       6716
# 45       6495
# 46      21693
# 47      33971
# 48       1434
# 49      32469
#
#                                                                                                Organisme  \
# 0                                                                 AGENCIA TRIBUTARIA MUNICIPAL DE MADRID
# 1   JEFATURA PROVINCIAL DE TRÁFICO DE MADRID
# 2   SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 3   SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 4                                                             SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 5                                                             SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 6                                                             SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 7                                                             SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 8   JEFATURA PROVINCIAL DE TRÁFICO DE MADRID
# 9                                                             SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 10                                                            SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 11  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 12  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 13  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 14  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 15  AGENCIA TRIBUTARIA ESTATAL MADRID
# 16  AGENCIA TRIBUTARIA ESTATAL MADRID
# 17  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 18  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 19  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 20  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 21  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 22  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 23  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 24  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 25  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 26  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 27  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 28                                                                  MADRID, AGENCIA TRIBUTARIA MUNICIPAL
# 29  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 30                                                            SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 31  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 32  AGENCIA TRIBUTARIA ESTATAL MADRID
# 33  AGENCIA TRIBUTARIA ESTATAL MADRID
# 34  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 35                                                            SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 36                                                         SUBDIRECCION GENERAL DE RECAUDACION DE MADRID
# 37  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 38  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 39  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 40  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 41  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 42  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 43  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 44  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 45  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 46  JEFATURA PROVINCIAL DE TRÁFICO DE MADRID
# 47  AGENCIA TRIBUTARIA ESTATAL MADRID
# 48  SUBDIRECCION GNAL GESTION MULTAS DE MADRID
# 49  JEFATURA PROVINCIAL DE TRÁFICO DE MADRID
#
#    user_phone                           user_email        nif  \
# 0   934881161              ccabellos@parkestil.com  46577285P
# 1   629475141                   txema@mendivil.com  16036491V
# 2   669286398                   avalverde@coac.net  52168714E
# 3   669286398                   avalverde@coac.net  52168714E
# 4   618520031               esteve.ribe@drivim.com  46514512W
# 5   618520031               esteve.ribe@drivim.com  46514512W
# 6   916252460                manolo@we-present.com  01396040D
# 7   916252460                manolo@we-present.com  01396040D
# 8   615426576            contabilidad@rolmovil.com  38145407E
# 9   916252460                manolo@we-present.com  01396040D
# 10  937339456                 esther@grupocant.net  39166889M
# 11        NaN                                  NaN  40602928Q
# 12        NaN                                  NaN  40602928Q
# 13  661738016                    frank@forocio.com  X2433787L
# 14  667413322                  info@unotech.com.es  44993859V
# 15  913106542          dionisio@tabernalibraria.es  05271600T
# 16  913106542          dionisio@tabernalibraria.es  05271600T
# 17        NaN                                  NaN  40602928Q
# 18  609099998           carlosnewtexline@gmail.com  38071464R
# 19  609099998           carlosnewtexline@gmail.com  38071464R
# 20        NaN                                  NaN  40602928Q
# 21  915348320           administracion@serenur.com  38451361F
# 22  915348320           administracion@serenur.com  38451361F
# 23  609099998           carlosnewtexline@gmail.com  38071464R
# 24  661738016                    frank@forocio.com  X2433787L
# 25        NaN                                  NaN  40602928Q
# 26        NaN                                  NaN  40602928Q
# 27        NaN                                  NaN  40602928Q
# 28  610700758               jsaumell@tupinamba.com  35106391L
# 29  934881161         mireiacabellos@parkestil.com  38555237S
# 30  610700758               jsaumell@tupinamba.com  35106391L
# 31  609020210  benjaminapariciodesiderio@gmail.com  07223733P
# 32        NaN                                  NaN  40602928Q
# 33  609099998           carlosnewtexline@gmail.com  38071464R
# 34  634999082                                  NaN  25445443Z
# 35  676471507                   lmherranz@yahoo.es  70821268J
# 36  932531411     rrhh@xvia-serviciosjuridicos.com  35059210B
# 37  915348320           administracion@serenur.com  38451361F
# 38  661738016                    frank@forocio.com  X2433787L
# 39  661738016                    frank@forocio.com  X2433787L
# 40  915348320           administracion@serenur.com  38451361F
# 41  915348320           administracion@serenur.com  38451361F
# 42  661738016                    frank@forocio.com  X2433787L
# 43  609099998           carlosnewtexline@gmail.com  38071464R
# 44  609099998           carlosnewtexline@gmail.com  38071464R
# 45  609099998           carlosnewtexline@gmail.com  38071464R
# 46  609099998           carlosnewtexline@gmail.com  38071464R
# 47  913106542          dionisio@tabernalibraria.es  05271600T
# 48        NaN                                  NaN  40602928Q
# 49  913106542          dionisio@tabernalibraria.es  05271600T
#
#                                name                            address_street  \
# 0                JAUME FERRER FORES                                DIPUTACIÓN
# 1             TXEMA MENDIBIL ALZOLA                           LORENZO AREILZA
# 2             ANA VALVERDE MATILLAS                              PL. PALMERES
# 3             ANA VALVERDE MATILLAS                              PL. PALMERES
# 4               JOAN CASANOVAS SOLE                                      ACER
# 5               JOAN CASANOVAS SOLE                                      ACER
# 6            MANUEL GIMENEZ LATORRE                     CONDE DE LOS GAITANES
# 7            MANUEL GIMENEZ LATORRE                     CONDE DE LOS GAITANES
# 8            DANIEL CARRILLO ROLDAN                                   ESQUEIS
# 9            MANUEL GIMENEZ LATORRE                     CONDE DE LOS GAITANES
# 10             SALVADOR RUBIO RUBIO                                  C/ ORION
# 11      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 12      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 13                 STEFAN SCHMUCKLE                       SIERRA DE GUADALUPE
# 14  FRANCISCO JAVIER TERRON COLLADO                       PLAZA DE GRANOLLERS
# 15          DIONISIO REDONDO ZABALA                                  SOTOMORA
# 16          DIONISIO REDONDO ZABALA                                  SOTOMORA
# 17      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 18              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 19              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 20      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 21            OSCAR NUÑEZ FERNANDEZ                          CALLE PINOS BAJA
# 22            OSCAR NUÑEZ FERNANDEZ                          CALLE PINOS BAJA
# 23              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 24                 STEFAN SCHMUCKLE                       SIERRA DE GUADALUPE
# 25      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 26      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 27      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 28        Mª TERESA PARRA COROMINAS                       C/ DOMENECH PASCUAL
# 29    FRANCISCO JOSÉ PUJOL MARTINEZ                                DIPUTACIÓN
# 30        Mª TERESA PARRA COROMINAS                       C/ DOMENECH PASCUAL
# 31         Mª ALMUDENA MARTINEZ REY               C/ PORTILLO DEL PARDO Nº 15
# 32      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 33              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 34                 JOSE BOTELLA GIL                     C/ JULIAN SANZ IBAÑEZ
# 35          VIRGINIA HERRANZ MARTIN  PI BRAJERO,  NAVE 96 APARTADO CORREOS 41
# 36       MAITE MORENTE DE LA FUENTE                       RONDA GENERAL MITRE
# 37            OSCAR NUÑEZ FERNANDEZ                          CALLE PINOS BAJA
# 38                 STEFAN SCHMUCKLE                       SIERRA DE GUADALUPE
# 39                 STEFAN SCHMUCKLE                       SIERRA DE GUADALUPE
# 40            OSCAR NUÑEZ FERNANDEZ                          CALLE PINOS BAJA
# 41            OSCAR NUÑEZ FERNANDEZ                          CALLE PINOS BAJA
# 42                 STEFAN SCHMUCKLE                       SIERRA DE GUADALUPE
# 43              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 44              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 45              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 46              CARLOS LOPEZ IBAÑEZ                             CTRA. EL PRAT
# 47          DIONISIO REDONDO ZABALA                                  SOTOMORA
# 48      PURIFICACION PANIAGUA MORAN   PASEO DE LOS PARQUES, 6, portal 18, 2ºD
# 49          DIONISIO REDONDO ZABALA                                  SOTOMORA
#
#    address_number address_zip             address_city address_province  \
# 0             304       08009                BARCELONA        BARCELONA
# 1      2 portal B       48993                    GETXO          VIZCAYA
# 2              23       08040                BARCELONA        BARCELONA
# 3              23       08040                BARCELONA        BARCELONA
# 4              44       08911                 BADALONA        BARCELONA
# 5              44       08911                 BADALONA        BARCELONA
# 6              62       28109              LA MORALEJA           MADRID
# 7              62       28109              LA MORALEJA           MADRID
# 8              21       08415          BIGUES I RIELLS        BARCELONA
# 9              62       28109              LA MORALEJA           MADRID
# 10              4       08228                 TERRASSA        BARCELONA
# 11            NaN       28109              LA MORALEJA           MADRID
# 12            NaN       28109              LA MORALEJA           MADRID
# 13             12       28229  VILLANUEVA DEL PARDILLO           MADRID
# 14             22       08207                 SABADELL        BARCELONA
# 15             11       28280              EL ESCORIAL           MADRID
# 16             11       28280              EL ESCORIAL           MADRID
# 17            NaN       28109              LA MORALEJA           MADRID
# 18             30       08038                BARCELONA        BARCELONA
# 19             30       08038                BARCELONA        BARCELONA
# 20            NaN       28109              LA MORALEJA           MADRID
# 21             51       28029                   MADRID           MADRID
# 22             51       28029                   MADRID           MADRID
# 23             30       08038                BARCELONA        BARCELONA
# 24             12       28229  VILLANUEVA DEL PARDILLO           MADRID
# 25            NaN       28109              LA MORALEJA           MADRID
# 26            NaN       28109              LA MORALEJA           MADRID
# 27            NaN       28109              LA MORALEJA           MADRID
# 28              3       08360             CANET DE MAR        BARCELONA
# 29            304       08009                BARCELONA        BARCELONA
# 30              3       08360             CANET DE MAR        BARCELONA
# 31            NaN       28023                   MADRID           MADRID
# 32            NaN       28109              LA MORALEJA           MADRID
# 33             30       08038                BARCELONA        BARCELONA
# 34             55       50017                 ZARAGOZA         ZARAGOZA
# 35            NaN       05230  NAVAS DEL MARQUES (LAS)            AVILA
# 36            169       08022                BARCELONA        BARCELONA
# 37             51       28029                   MADRID           MADRID
# 38             12       28229  VILLANUEVA DEL PARDILLO           MADRID
# 39             12       28229  VILLANUEVA DEL PARDILLO           MADRID
# 40             51       28029                   MADRID           MADRID
# 41             51       28029                   MADRID           MADRID
# 42             12       28229  VILLANUEVA DEL PARDILLO           MADRID
# 43             30       08038                BARCELONA        BARCELONA
# 44             30       08038                BARCELONA        BARCELONA
# 45             30       08038                BARCELONA        BARCELONA
# 46             30       08038                BARCELONA        BARCELONA
# 47             11       28280              EL ESCORIAL           MADRID
# 48            NaN       28109              LA MORALEJA           MADRID
# 49             11       28280              EL ESCORIAL           MADRID
#
#    expediente_tipo        notif_name notif_surname1 notif_surname2  \
# 0          opcion1             JAUME         FERRER          FORES
# 1          opcion1             TXEMA       MENDIBIL         ALZOLA
# 2          opcion1               ANA       VALVERDE       MATILLAS
# 3          opcion1               ANA       VALVERDE       MATILLAS
# 4          opcion1              JOAN      CASANOVAS           SOLE
# 5          opcion1              JOAN      CASANOVAS           SOLE
# 6          opcion1            MANUEL        GIMENEZ        LATORRE
# 7          opcion1            MANUEL        GIMENEZ        LATORRE
# 8          opcion1            DANIEL       CARRILLO         ROLDAN
# 9          opcion1            MANUEL        GIMENEZ        LATORRE
# 10         opcion1          SALVADOR          RUBIO          RUBIO
# 11         opcion1      PURIFICACION       PANIAGUA          MORAN
# 12         opcion1      PURIFICACION       PANIAGUA          MORAN
# 13         opcion1            STEFAN      SCHMUCKLE            NaN
# 14         opcion1  FRANCISCO JAVIER         TERRON        COLLADO
# 15         opcion1          DIONISIO        REDONDO         ZABALA
# 16         opcion1          DIONISIO        REDONDO         ZABALA
# 17         opcion1      PURIFICACION       PANIAGUA          MORAN
# 18         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 19         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 20         opcion1      PURIFICACION       PANIAGUA          MORAN
# 21         opcion1             OSCAR          NUÑEZ      FERNANDEZ
# 22         opcion1             OSCAR          NUÑEZ      FERNANDEZ
# 23         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 24         opcion1            STEFAN      SCHMUCKLE            NaN
# 25         opcion1      PURIFICACION       PANIAGUA          MORAN
# 26         opcion1      PURIFICACION       PANIAGUA          MORAN
# 27         opcion1      PURIFICACION       PANIAGUA          MORAN
# 28         opcion1         Mª TERESA          PARRA      COROMINAS
# 29         opcion1    FRANCISCO JOSÉ          PUJOL       MARTINEZ
# 30         opcion1         Mª TERESA          PARRA      COROMINAS
# 31         opcion1       Mª ALMUDENA       MARTINEZ            REY
# 32         opcion1      PURIFICACION       PANIAGUA          MORAN
# 33         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 34         opcion1              JOSE        BOTELLA            GIL
# 35         opcion1          VIRGINIA        HERRANZ         MARTIN
# 36         opcion1             MAITE        MORENTE   DE LA FUENTE
# 37         opcion1             OSCAR          NUÑEZ      FERNANDEZ
# 38         opcion1            STEFAN      SCHMUCKLE            NaN
# 39         opcion1            STEFAN      SCHMUCKLE            NaN
# 40         opcion1             OSCAR          NUÑEZ      FERNANDEZ
# 41         opcion1             OSCAR          NUÑEZ      FERNANDEZ
# 42         opcion1            STEFAN      SCHMUCKLE            NaN
# 43         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 44         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 45         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 46         opcion1            CARLOS          LOPEZ         IBAÑEZ
# 47         opcion1          DIONISIO        REDONDO         ZABALA
# 48         opcion1      PURIFICACION       PANIAGUA          MORAN
# 49         opcion1          DIONISIO        REDONDO         ZABALA
#
#    plate_number expediente_nnn expediente_eeeeeeeee expediente_d  \
# 0           NaN            NaN                  NaN          NaN
# 1       8727HKT            NaN                  NaN          NaN
# 2       3748LRB            NaN                  NaN          NaN
# 3       3748LRB            NaN                  NaN          NaN
# 4           NaN            911            304328031            1
# 5           NaN            911            555845723            9
# 6           NaN            911            304397606            8
# 7           NaN            911            713601522            3
# 8       9460LHT            NaN                  NaN          NaN
# 9           NaN            911            354358533            0
# 10          NaN            911            354319438            9
# 11      0268KPL            NaN                  NaN          NaN
# 12      5880KLR            NaN                  NaN          NaN
# 13      9962KNX            NaN                  NaN          NaN
# 14      5452KKC            NaN                  NaN          NaN
# 15          NaN            NaN                  NaN          NaN
# 16          NaN            NaN                  NaN          NaN
# 17      0268KPL            NaN                  NaN          NaN
# 18          NaN            NaN                  NaN          NaN
# 19      8462JKV            NaN                  NaN          NaN
# 20      0268KPL            NaN                  NaN          NaN
# 21      9769JPY            NaN                  NaN          NaN
# 22      9769JPY            NaN                  NaN          NaN
# 23      6121JFP            NaN                  NaN          NaN
# 24      1723MDY            NaN                  NaN          NaN
# 25      5880KLR            NaN                  NaN          NaN
# 26      5880KLR            NaN                  NaN          NaN
# 27      5880KLR            NaN                  NaN          NaN
# 28          NaN            NaN                  NaN          NaN
# 29      1434KDD            NaN                  NaN          NaN
# 30          NaN            911            352853602            9
# 31      8237LGM            NaN                  NaN          NaN
# 32          NaN            NaN                  NaN          NaN
# 33          NaN            NaN                  NaN          NaN
# 34      5632JRF            NaN                  NaN          NaN
# 35          NaN            911            354327323            0
# 36          NaN            NaN                  NaN          NaN
# 37      9769JPY            NaN                  NaN          NaN
# 38      9962KNX            NaN                  NaN          NaN
# 39      1723MDY            NaN                  NaN          NaN
# 40      9769JPY            NaN                  NaN          NaN
# 41      9769JPY            NaN                  NaN          NaN
# 42      9962KNX            NaN                  NaN          NaN
# 43      6121JFP            NaN                  NaN          NaN
# 44      6121JFP            NaN                  NaN          NaN
# 45      6121JFP            NaN                  NaN          NaN
# 46      6121JFP            NaN                  NaN          NaN
# 47          NaN            NaN                  NaN          NaN
# 48      0268KPL            NaN                  NaN          NaN
# 49      9257FGN            NaN                  NaN          NaN
#
#    expediente_lll expediente_aaaa expediente_exp_num
# 0             NaN             NaN                NaN
# 1             NaN             NaN                NaN
# 2             NaN             NaN                NaN
# 3             NaN             NaN                NaN
# 4             NaN             NaN                NaN
# 5             NaN             NaN                NaN
# 6             NaN             NaN                NaN
# 7             NaN             NaN                NaN
# 8             NaN             NaN                NaN
# 9             NaN             NaN                NaN
# 10            NaN             NaN                NaN
# 11            NaN             NaN                NaN
# 12            NaN             NaN                NaN
# 13            NaN             NaN                NaN
# 14            NaN             NaN                NaN
# 15            NaN             NaN                NaN
# 16            NaN             NaN                NaN
# 17            NaN             NaN                NaN
# 18            NaN             NaN                NaN
# 19            NaN             NaN                NaN
# 20            NaN             NaN                NaN
# 21            NaN             NaN                NaN
# 22            NaN             NaN                NaN
# 23            NaN             NaN                NaN
# 24            NaN             NaN                NaN
# 25            NaN             NaN                NaN
# 26            NaN             NaN                NaN
# 27            NaN             NaN                NaN
# 28            NaN             NaN                NaN
# 29            NaN             NaN                NaN
# 30            NaN             NaN                NaN
# 31            NaN             NaN                NaN
# 32            NaN             NaN                NaN
# 33            NaN             NaN                NaN
# 34            NaN             NaN                NaN
# 35            NaN             NaN                NaN
# 36            NaN             NaN                NaN
# 37            NaN             NaN                NaN
# 38            NaN             NaN                NaN
# 39            NaN             NaN                NaN
# 40            NaN             NaN                NaN
# 41            NaN             NaN                NaN
# 42            NaN             NaN                NaN
# 43            NaN             NaN                NaN
# 44            NaN             NaN                NaN
# 45            NaN             NaN                NaN
# 46            NaN             NaN                NaN
# 47            NaN             NaN                NaN
# 48            NaN             NaN                NaN
# 49            NaN             NaN                NaN
